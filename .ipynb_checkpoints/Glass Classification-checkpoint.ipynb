# %% [markdown]
# # Glass Classification

# %% [markdown]
# ## DataSet Info

# %% [markdown]
# >### Context
# This is a Glass Identification Data Set from UCI. It contains 10 attributes including id. The response is glass type(discrete 7 values)
#
# >### Content
# Attribute Information:
#
# >Id number: 1 to 214 (removed from CSV file).
#
# >RI: refractive indexNa: Sodium (unit measurement: weight percent in corresponding oxide, as are attributes 4-10)
#
# >Mg: Magnesium
#
# >Al: Aluminum
#
# >Si: Silicon
#
# >K: Potassium
#
# >Ca: Calcium
#
# >Ba: Barium
#
# >Fe: Iron
#
# >Type of glass: (class attribute)
#
# >-- 1 building_windows_float_processed
#
# >-- 2 building_windows_non_float_processed
#
# >-- 3 vehicle_windows_float_processed
#
# >-- 4 vehicle_windows_non_float_processed (none in this database)
#
# >-- 5 containers
#
# >-- 6 tableware
#
# >-- 7 headlamps
#
# >### Acknowledgements
# https://archive.ics.uci.edu/ml/datasets/Glass+Identification
# Source:
#
# >### Creator:
# B. German
# Central Research Establishment
# Home Office Forensic Science Service
# Aldermaston, Reading, Berkshire RG7 4PN
#
# >### Donor:
# Vina Spiehler, Ph.D., DABFT
# Diagnostic Products Corporation
# (213) 776-0180 (ext 3014)

# %% [markdown]
# ## Section 1: Importing Libraries and Dataset

# %% [markdown]
# #### 1.1 Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# #### 1.2 Importing the DataSet

# %%
glass = pd.read_csv('glass.csv')

# %% [markdown]
# ## Section 2: Correcting/Preprocessing the DataSet

# %%
glass
# Out:
#           RI     Na    Mg    Al     Si     K    Ca    Ba   Fe  Type
# 0    1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0     1
# 1    1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0     1
# 2    1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0     1
# 3    1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0     1
# 4    1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0     1
# ..       ...    ...   ...   ...    ...   ...   ...   ...  ...   ...
# 209  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0     7
# 210  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0     7
# 211  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0     7
# 212  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.0     7
# 213  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.0     7
#
# [214 rows x 10 columns]

# %%
glass.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 214 entries, 0 to 213
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   RI      214 non-null    float64
#  1   Na      214 non-null    float64
#  2   Mg      214 non-null    float64
#  3   Al      214 non-null    float64
#  4   Si      214 non-null    float64
#  5   K       214 non-null    float64
#  6   Ca      214 non-null    float64
#  7   Ba      214 non-null    float64
#  8   Fe      214 non-null    float64
#  9   Type    214 non-null    int64
# dtypes: float64(9), int64(1)
# memory usage: 16.8 KB

# %% [markdown]
# > Seems like there are no *missing/null* values in our DataSet.

# %% [markdown]
# ## Section 3: Exploring and Visualizing the data

# %%
glass['Type'].unique()
# Out:
# array([1, 2, 3, 5, 6, 7], dtype=int64)

# %% [markdown]
# There are 6 different types of glassess in our dataset which are classified by above values.

# %%
sns.barplot(y = glass['Type'].value_counts(sort=True), x = glass['Type'].value_counts(sort=True).index, )
plt.title('Quantity of each Glass type in our DataSet')
plt.xlabel('Type of Glass')
plt.ylabel('Number of occurences')
# Out:
# Text(0, 0.5, 'Number of occurences')

# %% [markdown]
# Glass type '1' and '2' have most number of repetitions compared to '3', '5', '6' and '7' whose occurences are all less than 30.

# %% [markdown]
# #### Now lets Compare different glass properties with glass type.

# %%
sns.set_theme(style="ticks")
g = sns.relplot(
    data=glass, hue = 'Type',
    x="Type", y="RI",
    palette="crest", marker="x", s=100,
)

# %%
sns.set_theme(style="ticks")
g = sns.relplot(
    data=glass, hue = 'Type',
    x="Type", y="Na",
    palette="crest", marker="x", s=100,
)

# %%
sns.set_theme(style="ticks")
g = sns.relplot(
    data=glass, hue = 'Type',
    x="Type", y="Mg",
    palette="crest", marker="x", s=100,
)

# %%
sns.set_theme(style="ticks")
g = sns.relplot(
    data=glass, hue = 'Type',
    x="Type", y="K",
    palette="crest", marker="x", s=100,
)

# %%
sns.set_theme(style="ticks")
g = sns.relplot(
    data=glass, hue = 'Type',
    x="Type", y="Al",
    palette="crest", marker="x", s=100,
)

# %%
sns.set_theme(style="ticks")
g = sns.relplot(
    data=glass, hue = 'Type',
    x="Type", y="Si",
    palette="crest", marker="x", s=100,
)

# %%
sns.set_theme(style="ticks")
g = sns.relplot(
    data=glass, hue = 'Type',
    x="Type", y="Ca",
    palette="crest", marker="x", s=100,
)

# %%
sns.set_theme(style="ticks")
g = sns.relplot(
    data=glass, hue = 'Type',
    x="Type", y="Ba",
    palette="crest", marker="x", s=100,
)

# %% [markdown]
# >From the above 6 visualizations, one can determine the ranges of diffenrt attributes in which a particular Glass type might be.

# %%
sns.pairplot(glass)

# %% [markdown]
# ## Section 4: Scaling and TrainTestSplit of Dataset

# %% [markdown]
# #### 4.1 Train Test Split

# %%
X = glass[['RI','Na','Mg', 'Al', 'K', 'Si', 'Ca', 'Ba', 'Fe']]
y = glass['Type']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)

# %% [markdown]
# #### 4.2 Scaling the DataSet
